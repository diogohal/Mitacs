# %% [markdown]
# # Brazilian Hydrometric Data

# %% [markdown]
# The goal of this notebook is to collect Brazilian Hydrometric Data from different stations. After this, we want to convert the information in CSV format to perform data analysis.

# %% [markdown]
# ## 1. Import the necessary libraries

# %%
import requests
import time
import csv
import pandas as pd
import json

# %% [markdown]
# ## 2. Search for all stations for a specific river

# %%
json_info = []
for page in range(20):    
    print(f'Loading page {page}')
    while(True):
        all_stations = requests.get(f'https://www.snirh.gov.br/hidroweb/rest/api/dadosHistoricos?tipoEstacao=F&size=5000&page={page}')
        if(all_stations.status_code != 200):
            print(f'FAILED! error: {all_stations.status_code}')
        else:
            print('Successful')
            break

    byte_string = all_stations.content 
    json_data = json.loads(byte_string.decode('utf-8'))
    if(len(json_data['content']) == 0):
        break
    json_info.append(json_data)
# Out:
# Loading page 0
# Successful
# Loading page 1
# Successful
# Loading page 2
# Successful
# Loading page 3
# Successful
# Loading page 4
# Successful
# Loading page 5
# Successful
# Loading page 6
# Successful
# Loading page 7
# Successful
# Loading page 8
# Successful
# Loading page 9
# Successful
# Loading page 10
# Successful
# Loading page 11
# FAILED! error: 504
# Successful
# Loading page 12
# Successful
# Loading page 13
# FAILED! error: 504
# FAILED! error: 504
# Successful
# Loading page 14
# Successful
# Loading page 15
# Successful
# Loading page 16
# Successful
# Loading page 17
# Successful

# %%
# Obtain all the stations
stations_records = []
for js in json_info:
    for stat in js['content']:
        stations_records.append({**stat})

# Convert to a pandas Dataframe
df_stations = pd.DataFrame(stations_records).drop_duplicates()

# %%
df_stations = pd.read_csv('dados_convencionais.csv', sep=',')
df_stations[df_stations.codigoNomeSubBacia == '86 - RIO TAQUARI'][['nome','latitude','longitude']].to_csv('taquari.csv', sep=',', index=False)

# %% [markdown]
# ## 3. Collect data from the stations and convert to CSV format

# %%
with open('../teste2.txt', 'r') as txt:
    string = txt.read()

arr = []
for i in string.split(' - '):
    if(i.isnumeric() and len(i) > 3):
        arr.append(i)

for i in arr:
    if i in df_stations.id.values:
        print(i)

# %%
df_stations[['nome', 'latitude', 'longitude']].to_csv('stations_located.csv', sep=',', index=False)

# %%
df_stations[df_stations.nome == 'PCH MORRO GRANDE BARRAMENTO']
# Out:
#              id                         nome    tipoEstacao  codigoAdicional  \
# 15882  86125100  PCH MORRO GRANDE BARRAMENTO  Fluviométrica              NaN
#
#                      codigoNomeBacia codigoNomeSubBacia    nomeRio  \
# 15882  8 - ATLÂNTICO, TRECHO SUDESTE   86 - RIO TAQUARI  RIO ITUIM
#
#               nomeEstado  nomeMunicipio responsavelSigla operadoraSigla  \
# 15882  RIO GRANDE DO SUL  MUITOS CAPÕES     MORRO GRANDE   MORRO GRANDE
#
#        areaDrenagem  latitude  longitude  altitude
# 15882         640.0  -28.5589   -51.3111     631.0

# %%
df_stations[df_stations.nomeRio == 'RIO PARANÁ'].sort_values(by='ultimaAtualizacao')
# Out:
#              id  codigoAdicional   aneelPlu    aneelFlu  \
# 905   252454356         64902900        NaN  64902900.0
# 902   252454354         64902750        NaN  64902750.0
# 900   252454352         64902650        NaN  64902650.0
# 17    222851580         63995080        NaN  63995080.0
# 896   250454240         64896200        NaN  64896200.0
# 904   252554350         64902850        NaN  64902850.0
# 903   252454355         64902800        NaN  64902800.0
# 901   252454353         64902700        NaN  64902700.0
# 899   252454351         64902600        NaN  64902600.0
# 897   252454360         64902000        NaN  64902000.0
# 19    224353101         64575000        NaN  64575000.0
# 906   252654361         64918000        NaN  64918000.0
# 898   252454340         64902080        NaN  64902080.0
# 895   240254140         64838000        NaN  64838000.0
# 1264  225853360         64580010        NaN  64580010.0
# 1300  245454270         64894600        NaN  64894600.0
# 224   243054190         64860000  2454000.0  64860000.0
# 18    202351221         62020080        NaN  62020080.0
# 344   205251380         63010000        NaN  63010000.0
# 730   202551220         62020000        NaN         NaN
#
#                                  nome  latitude  longitude  altitude  \
# 905      JUSANTE ENSECADEIRA  (LP-RM) -25.41580  -54.59500     148.0
# 902     MONTANTE ENSECADEIRA  (CD-RM) -25.41220  -54.58830     122.0
# 900    PARAMENTO DE JUSANTE (U13-U14) -25.40830  -54.58780     120.0
# 17     UHE PORTO PRIMAVERA BARRAMENTO -22.48170  -52.95640     280.0
# 896                       SOL DE MAIO -25.07917  -54.40000       NaN
# 904      JUSANTE ENSECADEIRA  (CD-RM) -25.41690  -54.59000     148.0
# 903     MONTANTE ENSECADEIRA  (LP-RM) -25.41140  -54.59310     148.0
# 901   PARAMENTO DE JUSANTE  (U3-U4TE) -25.40780  -54.59170     120.0
# 899    PARAMENTO DE JUSANTE (U16-U17) -25.40860  -54.58610     120.0
# 897        UHE ITAIPU PEDRO ORTELLADO -25.41310  -54.61530     225.0
# 19          UHE ITAIPU PORTO SÃO JOSÉ -22.71810  -53.17670     232.0
# 906                    UHE ITAIPU R-4 -25.44170  -54.60280       NaN
# 898             UHE ITAIPU DEFLUÊNCIA -25.40000  -54.58330       NaN
# 895   UHE ITAIPU GUAÍRA BRAÇO DIREITO -24.04250  -54.23420       NaN
# 1264                  PORTO QUERÊNCIA -22.96670  -53.60280       NaN
# 1300                     PUERTO INDIO -24.90690  -54.45720       NaN
# 224            PORTO MENDES GONÇALVES -24.50000  -54.33306     150.0
# 18      UHE ILHA SOLTEIRA  BARRAMENTO -20.37970  -51.36860       NaN
# 344                 UHE JUPIÁ JUSANTE -20.85530  -51.63500     251.0
# 730         UHE ILHA SOLTEIRA JUSANTE -20.42330  -51.37690     278.0
#
#                     ultimaAtualizacao  baciaCodigo  ...   rioCodigo  \
# 905         2011-06-02 03:00:00+00:00            6  ...  60001000.0
# 902         2011-06-02 03:00:00+00:00            6  ...  60001000.0
# 900         2014-09-12 03:00:00+00:00            6  ...  60001000.0
# 17          2015-03-11 03:00:00+00:00            6  ...  60001000.0
# 896  2018-12-11 19:16:41.033000+00:00            6  ...  60001000.0
# 904  2018-12-11 19:39:59.610000+00:00            6  ...  60001000.0
# 903  2018-12-11 19:40:37.080000+00:00            6  ...  60001000.0
# 901  2018-12-11 19:41:05.550000+00:00            6  ...  60001000.0
# 899  2018-12-11 19:42:04.543000+00:00            6  ...  60001000.0
# 897  2018-12-18 18:17:26.153000+00:00            6  ...  60001000.0
# 19   2018-12-18 18:17:26.230000+00:00            6  ...  60001000.0
# 906  2018-12-18 18:17:26.357000+00:00            6  ...  60001000.0
# 898  2018-12-19 19:00:03.707000+00:00            6  ...  60001000.0
# 895         2020-03-06 03:00:00+00:00            6  ...  60001000.0
# 1264        2020-10-30 03:00:00+00:00            6  ...  60001000.0
# 1300        2020-10-30 03:00:00+00:00            6  ...  60001000.0
# 224  2021-05-24 17:12:21.520000+00:00            6  ...  60001000.0
# 18          2021-08-18 03:00:00+00:00            6  ...  60001000.0
# 344  2022-09-29 15:04:09.167000+00:00            6  ...  60001000.0
# 730                               NaT            6  ...  60001000.0
#
#      estadoCodigo municipioCodigo responsavelCodigo operadoraCodigo  \
# 905            22        22082000                90              90
# 902            22        22082000                90              90
# 900            22        22082000                90              90
# 17             21        21443800                 6               6
# 896            22        22160500                90              90
# 904            22        22082000                90              90
# 903            22        22082000                90              90
# 901            22        22082000                90              90
# 899            22        22082000                90              90
# 897            63        63000000                90              90
# 19             22        22260000                90              90
# 906            22        22082000                90              90
# 898            22        22082000                90              90
# 895            22        22088000                90              90
# 1264           22        22211000                90              90
# 1300           63        63000000                90              90
# 224            22        22146000                 1               1
# 18             21        21206700              1062            1062
# 344            21        21111000              1062            1062
# 730            21        21206700                 6               6
#
#                   menorDataPeriodo              maiorDataPeriodo  \
# 905                            NaN                           NaN
# 902                            NaN                           NaN
# 900                            NaN                           NaN
# 17    2008-10-21T00:00:00.000+0000  2024-05-28T12:00:00.000+0000
# 896                            NaN                           NaN
# 904                            NaN                           NaN
# 903                            NaN                           NaN
# 901                            NaN                           NaN
# 899                            NaN                           NaN
# 897   2015-11-01T03:00:00.000+0000  2020-07-21T18:00:00.000+0000
# 19    2009-12-14T00:00:00.000+0000  2024-05-30T12:00:00.933+0000
# 906   2015-11-01T03:00:00.000+0000  2024-05-24T02:00:00.000+0000
# 898   2016-11-18T06:00:00.000+0000  2023-09-26T02:00:00.000+0000
# 895   2015-11-01T03:00:00.000+0000  2024-05-30T05:00:00.173+0000
# 1264                           NaN                           NaN
# 1300                           NaN                           NaN
# 224                            NaN                           NaN
# 18    2008-10-21T00:00:00.000+0000  2024-05-30T08:00:00.523+0000
# 344   2008-10-13T00:00:00.000+0000  2022-06-13T17:00:00.000+0000
# 730                            NaN                           NaN
#
#       responsavelSigla  operadoraSigla    tipoEstacao
# 905             ITAIPU          ITAIPU  Fluviométrica
# 902             ITAIPU          ITAIPU  Fluviométrica
# 900             ITAIPU          ITAIPU  Fluviométrica
# 17                CESP            CESP  Fluviométrica
# 896             ITAIPU          ITAIPU  Fluviométrica
# 904             ITAIPU          ITAIPU  Fluviométrica
# 903             ITAIPU          ITAIPU  Fluviométrica
# 901             ITAIPU          ITAIPU  Fluviométrica
# 899             ITAIPU          ITAIPU  Fluviométrica
# 897             ITAIPU          ITAIPU  Fluviométrica
# 19              ITAIPU          ITAIPU  Fluviométrica
# 906             ITAIPU          ITAIPU  Fluviométrica
# 898             ITAIPU          ITAIPU  Fluviométrica
# 895             ITAIPU          ITAIPU  Fluviométrica
# 1264            ITAIPU          ITAIPU  Fluviométrica
# 1300            ITAIPU          ITAIPU  Fluviométrica
# 224                ANA             ANA  Fluviométrica
# 18          RIO PARANÁ      RIO PARANÁ  Fluviométrica
# 344         RIO PARANÁ      RIO PARANÁ  Fluviométrica
# 730               CESP            CESP  Fluviométrica
#
# [20 rows x 26 columns]

# %%
df_stations = pd.read_csv('stations.csv', sep=',')
df_stations['ultimaAtualizacao'] = pd.to_datetime(df_stations['ultimaAtualizacao'], format='%Y-%m-%dT%H:%M:%S.%f%z')

# %% [markdown]
# Collect rivers with the most recent stations updates

# %%
rivers = df_stations[df_stations.ultimaAtualizacao > query_date].groupby('nomeRio').count().sort_values(by='id', ascending=False).head(15).index

# %%
for year in range(2010, 2024):
    query_date = pd.to_datetime(f'{year+1}-01-01T00:00:00.000+0000', format='%Y-%m-%dT%H:%M:%S.%f%z')
    periodoInicial = f'{year}-01-01T04:00:00.000Z'
    periodoFinal = f'{year+1}-01-01T04:00:00.000Z'
    count_try = 10
    rivers = ['RIO PARANÁ', 'RIO PARANAPANEMA', 'RIO PARAMIRIM', 'RIO JOANES', 'RIO CHAPECOZINHO']
    for river in rivers:
        arr_stations = df_stations[df_stations.nomeRio == river].id.values
        for stat in arr_stations:
            print(f'STATION: {stat}')
            success = False
            for count in range(1, count_try):
                x = requests.get(f'https://www.snirh.gov.br/hidroweb/rest/api/documento/gerarTelemetricas?codigosEstacoes={stat}&tipoArquivo=3&periodoInicial={periodoInicial}&periodoFinal={periodoFinal}')
                if(x.status_code == 200):
                    success = True
                    break
                elif(x.status_code == 500):
                    print('Date is probably out of range')
                    break
                print(f'Try: {count}   Response: {x.status_code}')
            if(success):
                filename = f'{river}-{stat}-{year}'
                saveMetrisRecord(x.content, stat, filename)
                print('Successful\n')
            else:
                print('Failed\n')
# Out:
# STATION: 222851580
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 202351221
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 224353101
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 243054190
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 205251380
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 202551220
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 240254140
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 250454240
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454360
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454340
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454351
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454352
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454353
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454354
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454355
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252554350
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454356
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252654361
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 225853360
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 245454270
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Successful
#
# STATION: 231149230
# Successful
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Successful
#
# STATION: 231149230
# Successful
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Successful
#
# STATION: 231149230
# Try: 1   Response: 504
# Successful
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Successful
#
# STATION: 231149230
# Successful
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Successful
#
# STATION: 231149230
# Successful
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Successful
#
# STATION: 231149230
# Successful
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 231149230
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264552230
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264552250
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 503
# Failed
#
# STATION: 224353101
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 243054190
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 205251380
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 202551220
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 240254140
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 252454340
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454351
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454352
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454353
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454354
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454355
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252554350
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 231149230
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 230449500
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 225550250
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 132542091
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 132642130
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 132642120
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 503
# Failed
#
# STATION: 264552230
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264552250
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264452240
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264752300
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264651560
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 222851580
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 202351221
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 224353101
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 243054190
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 205251380
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 202551220
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 231149230
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 230449500
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 225550250
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 132542091
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 132642130
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264552230
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Successful
#
# STATION: 231149230
# Successful
#
# STATION: 230449500
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Successful
#
# STATION: 264452240
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264752300
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 503
# Failed
#
# STATION: 243054190
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 205251380
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 231149230
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 230449500
# Try: 1   Response: 504
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Successful
#
# STATION: 264452240
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264752300
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 264651560
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Successful
#
# STATION: 224353101
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 231149230
# Try: 1   Response: 504
# Successful
#
# STATION: 230449500
# Successful
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Successful
#
# STATION: 202351221
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 224353101
# Try: 1   Response: 504
# Successful
#
# STATION: 243054190
# Date is probably out of range
# Failed
#
# STATION: 205251380
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Successful
#
# STATION: 250454240
# Date is probably out of range
# Failed
#
# STATION: 252454360
# Successful
#
# STATION: 252454340
# Successful
#
# STATION: 252454351
# Date is probably out of range
# Failed
#
# STATION: 252454352
# Date is probably out of range
# Failed
#
# STATION: 252454353
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Successful
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 231149230
# Try: 1   Response: 504
# Successful
#
# STATION: 230449500
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 225550250
# Date is probably out of range
# Failed
#
# STATION: 132542091
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 132642130
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Successful
#
# STATION: 264552230
# Successful
#
# STATION: 264552250
# Successful
#
# STATION: 264452240
# Successful
#
# STATION: 264752300
# Successful
#
# STATION: 264651560
# Successful
#
# STATION: 222851580
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 202351221
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 224353101
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 243054190
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 205251380
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Successful
#
# STATION: 202551220
# Date is probably out of range
# Failed
#
# STATION: 240254140
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 250454240
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454360
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454340
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454351
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454352
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 252454353
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Date is probably out of range
# Failed
#
# STATION: 252454354
# Date is probably out of range
# Failed
#
# STATION: 252454355
# Date is probably out of range
# Failed
#
# STATION: 252554350
# Date is probably out of range
# Failed
#
# STATION: 252454356
# Date is probably out of range
# Failed
#
# STATION: 252654361
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed
#
# STATION: 225853360
# Date is probably out of range
# Failed
#
# STATION: 245454270
# Date is probably out of range
# Failed
#
# STATION: 245749580
# Date is probably out of range
# Failed
#
# STATION: 230949220
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 231149230
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 230449500
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 225550250
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 132542091
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Successful
#
# STATION: 132642130
# Successful
#
# STATION: 132642120
# Successful
#
# STATION: 130242350
# Successful
#
# STATION: 132542090
# Successful
#
# STATION: 130042330
# Successful
#
# STATION: 123638260
# Successful
#
# STATION: 123638250
# Successful
#
# STATION: 125038191
# Successful
#
# STATION: 124038221
# Successful
#
# STATION: 264652190
# Try: 1   Response: 504
# Try: 2   Response: 504
# Try: 3   Response: 504
# Try: 4   Response: 504
# Try: 5   Response: 504
# Try: 6   Response: 504
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264552230
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264552250
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264452240
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264752300
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 503
# Try: 7   Response: 503
# Try: 8   Response: 503
# Try: 9   Response: 503
# Failed
#
# STATION: 264651560
# Try: 1   Response: 503
# Try: 2   Response: 503
# Try: 3   Response: 503
# Try: 4   Response: 503
# Try: 5   Response: 503
# Try: 6   Response: 504
# Try: 7   Response: 504
# Try: 8   Response: 504
# Try: 9   Response: 504
# Failed

# %%
def saveMetrisRecord(byte_string, station_number, filename):
    json_data = json.loads(byte_string.decode('utf-8'))
    medicoes_records = []
    for record in json_data:
        for medicoes in record.pop('medicoes', []):
            medicoes_records.append({**record, **medicoes})

    # Create a DataFrame from the expanded records
    medicoes_df = pd.DataFrame(medicoes_records)
    medicoes_df.to_csv(f'{filename}.csv', sep=',', index=False)

# %%
display(medicoes_df.iloc[:,36:].head())
len(medicoes_df)
# Out:
#    horQChuva horChuva  horQNivelAdotado  horNivelAdotado  horQVazao horVazao
# 0        0.0     None               0.0          25709.0        NaN     None
# 1        0.0     None               0.0          25709.0        NaN     None
# 2        0.0     None               0.0          25709.0        NaN     None
# 3        0.0     None               0.0          25709.0        NaN     None
# 4        0.0     None               0.0          25710.0        NaN     None
# 8747

# %%
test = pd.read_csv('./Data/2023/RIO JOANES-123638260-2023.csv', sep=',')
test.iloc[:,36:]
# Out:
#      horQChuva  horChuva  horQNivelAdotado  horNivelAdotado  horQVazao  \
# 0          NaN       NaN               0.0            222.0        NaN
# 1          NaN       NaN               0.0            222.0        NaN
# 2          NaN       NaN               0.0            222.0        NaN
# 3          NaN       NaN               0.0            222.0        NaN
# 4          NaN       NaN               0.0            222.0        NaN
# ..         ...       ...               ...              ...        ...
# 497        NaN       NaN               0.0            220.0        NaN
# 498        NaN       NaN               0.0            220.0        NaN
# 499        NaN       NaN               0.0            220.0        NaN
# 500        NaN       NaN               0.0            220.0        NaN
# 501        NaN       NaN               0.0            220.0        NaN
#
#      horVazao
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 497       NaN
# 498       NaN
# 499       NaN
# 500       NaN
# 501       NaN
#
# [502 rows x 6 columns]
